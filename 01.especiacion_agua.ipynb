# %% [markdown]
# Problema 1
# 🌍 Efecto del Aumento de CO₂ Atmosférico sobre el pH del Océano
# Objetivo
# Simular cómo cambia el pH del agua de mar a medida que aumenta la concentración de dióxido de carbono (CO₂) en la atmósfera, un fenómeno directamente asociado al calentamiento global y la acidificación oceánica.
#
# Contexto
# La concentración actual de CO₂ en la atmósfera es de aproximadamente 420 ppm, lo que equivale a una presión parcial de alrededor de log P(CO₂) = -3.5 en atmósferas.
#
# Se espera que, si las emisiones continúan, las concentraciones de CO₂ puedan aumentar hasta:
#
# 560 ppm (~doble preindustrial): log P(CO₂) ≈ -3.25
# 840 ppm (escenario extremo): log P(CO₂) ≈ -3.0
# El aumento de CO₂ provoca un descenso del pH oceánico debido a su disolución y formación de ácido carbónico:
#
#
# Este ejercicio permite explorar este efecto en equilibrio, utilizando una solución marina simplificada.
#
# Instrucciones
# Simula tres escenarios con diferente presión parcial de CO₂:
#
# Condición actual: log P(CO₂) = -3.5 (≈ 420 ppm)
# Escenario de emisiones moderadas: log P(CO₂) = -3.25 (≈ 560 ppm)
# Escenario extremo: log P(CO₂) = -3.0 (≈ 840 ppm)
# Observa los cambios en:
#
# pH
# Distribución de especies de carbono (CO₂, HCO₃⁻, CO₃²⁻)
# Índice de saturación de calcita o aragonita

# %% [markdown]
# # PROCEDIMIENTO MOBAXTERM PHREEQC

# %% [markdown]
# ![Captura de pantalla 2026-04-27 165541.png](attachment:76969740-d81e-400a-a6af-35738801c2bb.png)

# %% [markdown]
# # PH y CO2.oceano

# %% [markdown]
# ![Captura de pantalla 2026-04-27 203508.png](attachment:df4407c1-1067-4987-97f2-9ef539d6e076.png)

# %% [markdown]
# # HCO3.oceano

# %% [markdown]
# ![image.png](attachment:e3bdcaa3-4e94-4a73-8204-8c22e4d17166.png)
# ![image.png](attachment:312a479c-b0cd-48ed-a3c6-caf289cbca03.png)

# %% [markdown]
# # CO3.oceano

# %% [markdown]
# ![image.png](attachment:d6cf2582-4eb8-452a-a791-57ba464cf270.png)
# ![image.png](attachment:cdb21e7d-61f2-45cc-afe8-df814c29d18b.png)
# ![image.png](attachment:b2e3b8c2-e4ed-45dd-9ef1-717426f9e201.png)

# %% [markdown]
# # Escenarios simulados

# %% [markdown]
# Escenario real: log PCO₂ = -3,5 (~420 ppm)
#
# Escenario moderado: log PCO₂ = -3,25 (~560 ppm)
#
# Escenario extremo: log PCO₂ = -3,0 (~840 ppm)
#
# ![image.png](attachment:fb00d04d-6390-4d6f-9ae9-544ee180cb71.png)
#
# # Análisis de resultados
#
# El incremento de CO₂ atmosférico produce una disminución progresiva del pH , pasando de 8,36 en condiciones actuales a 7,93 en el escenario extremo. Este comportamiento evidencia un proceso claro de acidificación oceánica .
#
# Desde el punto de vista de la especiación del carbono:
#
# El CO₂ disuelto (CO₂(aq)) aumenta significativamente con la presión parcial de CO₂.
# El bicarbonato (HCO₃⁻) también aumenta, aunque de forma más moderada.
# El carbonato (CO₃²⁻) disminuye , indicando un desplazamiento del equilibrio hacia especies más protonadas.
#
# Este cambio es consistente con el sistema carbonato:
#
# CO₂ + H₂O ⇌ H₂CO₃ ⇌ HCO₃⁻ ⇌ CO₃²⁻
