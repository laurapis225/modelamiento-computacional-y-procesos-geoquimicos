# %% [markdown]
# # Problema: Acuífero detrítico

# %% [markdown]
# ## PROCEDIMIENTO MOBAXTERM

# %% [markdown]
# ![image.png](attachment:f64c56e2-13b5-4397-8dc0-cb48591c4fa4.png)

# %% [markdown]
# ## Problema: intercambio catiónico en un acuífero detrítico

# %% [markdown]
# Se evalúa si la cantidad de intercambiador catiónico X calculada a partir de las propiedades del acuífero corresponde a 4 mmoles.
#
# Datos:
#
# Densidad de conjunto:
# - ρb = 1.86 g/cm³
# - Porosidad: θ = 0.35
#
# Capacidad de intercambio catiónico:
# - CEC = 75 meq/100 g

# %%
rho_b = 1.86      # g/cm3
theta = 0.35      # porosidad
CEC = 75          # meq/100 g

# Convertir CEC a meq/g
CEC_meq_g = CEC / 100

# Masa de sólido por litro de agua poral
masa_solido_g = (rho_b / theta) * 1000

# Capacidad total de intercambio
X_meq = masa_solido_g * CEC_meq_g

# Convertir meq a equivalentes
X_eq = X_meq / 1000

# Convertir a mmol de carga equivalente
X_mmol = X_eq * 1000

print("Masa de sólido por L de agua poral:", round(masa_solido_g, 2), "g")
print("Intercambiador X:", round(X_meq, 2), "meq")
print("Intercambiador X:", round(X_eq, 3), "eq")
print("Intercambiador X:", round(X_mmol, 2), "mmol equivalentes")
# Out:
# Masa de sólido por L de agua poral: 5314.29 g
# Intercambiador X: 3985.71 meq
# Intercambiador X: 3.986 eq
# Intercambiador X: 3985.71 mmol equivalentes

# %% [markdown]
# ## Resultado

# %% [markdown]
# La masa de sólido asociada a 1 L de agua poral es aproximadamente 5314.29 g.
#
# Con una CEC de 0.75 meq/g, la capacidad total de intercambio es:
#
# [ X = 5314.29 \times 0.75 = 3985.71 , \text{meq} ]
#
# Esto equivale a:
#
# [ X = 3.986 , \text{eq} ]
#
# o aproximadamente:
#
# [ X = 3985.71 , \text{mmol equivalentes} ]

# %% [markdown]
# ## INTERPRETACIÓN

# %% [markdown]
# El acuífero actúa como un sistema altamente reactivo, donde el intercambio catiónico, favorecido por la alta CEC y la saturación inicial en Ca²⁺ controla la evolución química durante la intrusión marina, produciendo liberación de Ca²⁺, retención de Na⁺ y un retardo significativo en el avance geoquímico de la salinización.
